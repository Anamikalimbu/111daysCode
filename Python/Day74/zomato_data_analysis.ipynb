# %% [markdown]
# **Zomato Data Analysis Using Python**
#
# It is important to understand customer perferences and restaurant trends to make informed business decisions in food industry.
#
# Do more restaurants provide online delivery compared to offline services ?
#
# Which types of restaurants are most favoured by the general public?
#
# What price range do couples prefer for dining out ?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataframe = pd.read_csv("../Day74/Zomato-data- (1).csv")
print(dataframe.head())

# %% [markdown]
# Data Cleaning and Preparation Before moving further we need to clean and process the data.
#
# Convert the rate column to a float by removing denominator characters.
# dataframe['rate']=dataframe['rate'].apply(handleRate)
#
# Applies the handleRate function to clean and convert each rating value in the 'rate' column

# %%
def handleRate(value):
  value = str(value).split('/')
  value = value[0]
  return float(value)

dataframe['rate']=dataframe['rate'].apply(handleRate)
print(dataframe.head())

# %%
# Getting summary of the dataframe use df.info()
dataframe.info()

# %%
print(dataframe.isnull().sum())

# %% [markdown]
# Exploring Restaurant Types
#
# Lets see the listed_in(type) column to identify popular categories.

# %%
sns.countplot(x=dataframe['listed_in(type)'])
plt.xlabel("Types of restaurant")

# %% [markdown]
# # Conclusion: The majority of the restaurant fall into the dining category.

# %%
# Votes by Restaurant Type
# Here we get the count of votes for each category.
grouped_data = dataframe.groupby('listed_in(type)')['votes'].sum()
result = pd.DataFrame({"votes": grouped_data})
plt.plot(result, c="green",marker='o')
plt.xlabel("Type of restaurant")
plt.ylabel('Votes')

# %% [markdown]
# # Conclusion: Dining restaurants are preferred by a larger number of individuals.

# %%
# Identify the most voted Restaurant
# Find the restaurant with the highest number of votes.
max_votes = dataframe["votes"].max()
restaurant_with_max_votes = dataframe.loc[dataframe['votes']==max_votes,'name']

print("Restaurant(s) with maximum votes:")
print(restaurant_with_max_votes)

# %%
# Step 6: Online Order Availability
# Exploring the online_order column to see how many restaurants accept online orders.
sns.countplot(x=dataframe['online_order'])

# %% [markdown]
# # Conclusion: This suggests that a majority of the restaurant di nir accept online orders.

# %%
# Step 7:Analyze Ratings
# Checking the distribution of ratings from the rate column.
plt.hist(dataframe['rate'],bins=5)
plt.title('Ratings Distribution')
plt.show()

# %% [markdown]
# # The majority of restaurants received ratings ranging from 3.5 to 4

# %%
#Step 8: Approximate Costs for couples
# Analyze the approx_cost(for two people) column to find the preferred price range.
couple_data=dataframe['approx_cost(for two people)']
sns.countplot(x=couple_data)

# %%
# Conclusion: The majority of couples prefers restaurants with an approximate cost of 300 rupees.

# %%
#Step 9: Rating comparision - Online vs Offline Orders
#Compare ratings between restaurants that accept online orders and those that don't

# %%
plt.figure(figsize=(6,6))
sns.boxplot(x='online_order',y='rate',data=dataframe)

# %%
#Step 10: Order Mode Prefrences by Restaurant Type
#Find the relationship between order mode (online_order) and restaurant type (listed_in(type))
pivot_table = dataframe.pivot_table(index='listed_in(type)',columns='online_order',aggfunc="size",fill_value=0) #Size counts number
sns.heatmap(pivot_table,annot=True, cmap="YlGnBu", fmt='d') #Annot shows number and fmt='d' shows number in decimal
plt.title("Heatmap")
plt.xlabel("Online Order")
plt.ylabel("Listed In (Type)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 #Step 10: Order Mode Prefrences by Restaurant Type
#       2 #Find the relationship between order mode (online_order) and restaurant type (listed_in(type))
# ----> 3 pivot_table = dataframe.pivot_table(index='listed_in(type)',columns='online_order',aggfunc="size",fill_value=0) #Size counts number
#       4 sns.heatmap(pivot_table,annot=True, cmap="YlGnBu", fmt='d') #Annot shows number and fmt='d' shows number in decimal
#       5 plt.title("Heatmap")
#       6 plt.xlabel("Online Order")
#
# NameError: name 'dataframe' is not defined
